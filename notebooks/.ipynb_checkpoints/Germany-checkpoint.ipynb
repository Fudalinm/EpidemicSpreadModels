# %%
import sys
sys.path.insert(1, '../model')
import model

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.ticker import ScalarFormatter
import optuna
optuna.logging.disable_default_handler()
import pandas as pd
pd.plotting.register_matplotlib_converters()
import seaborn as sns
from scipy.integrate import solve_ivp

# %%
raw = pd.read_csv("../data/covid_19_data.csv")

# %%
raw
# Out:
#          SNo ObservationDate Province/State  Country/Region  \
# 0          1      01/22/2020          Anhui  Mainland China
# 1          2      01/22/2020        Beijing  Mainland China
# 2          3      01/22/2020      Chongqing  Mainland China
# 3          4      01/22/2020         Fujian  Mainland China
# 4          5      01/22/2020          Gansu  Mainland China
# ...      ...             ...            ...             ...
# 14806  14807      04/13/2020        Wyoming              US
# 14807  14808      04/13/2020       Xinjiang  Mainland China
# 14808  14809      04/13/2020          Yukon          Canada
# 14809  14810      04/13/2020         Yunnan  Mainland China
# 14810  14811      04/13/2020       Zhejiang  Mainland China
#
#                Last Update  Confirmed  Deaths  Recovered
# 0          1/22/2020 17:00        1.0     0.0        0.0
# 1          1/22/2020 17:00       14.0     0.0        0.0
# 2          1/22/2020 17:00        6.0     0.0        0.0
# 3          1/22/2020 17:00        1.0     0.0        0.0
# 4          1/22/2020 17:00        0.0     0.0        0.0
# ...                    ...        ...     ...        ...
# 14806  2020-04-13 23:15:42      275.0     1.0        0.0
# 14807  2020-04-13 23:15:42       76.0     3.0       73.0
# 14808  2020-04-13 23:15:42        8.0     0.0        0.0
# 14809  2020-04-13 23:15:42      184.0     2.0      174.0
# 14810  2020-04-13 23:15:42     1267.0     1.0     1239.0
#
# [14811 rows x 8 columns]

# %%
data_cols = ["Infected", "Deaths", "Recovered"]
data_cols_all = ["Confirmed", "Infected", "Deaths", "Recovered"]
df = raw.rename({"ObservationDate": "Date", "Province/State": "Province"}, axis=1)
df["Date"] = pd.to_datetime(df["Date"])
df["Country"] = df["Country/Region"]
df.loc[df["Country"] == "Diamond Princess", ["Country", "Province"]] = ["Others", "Diamond Princess"]
df["Infected"] = df["Confirmed"] - df["Deaths"] - df["Recovered"]
df[data_cols_all] = df[data_cols_all].astype(np.int64)
ncov_df_ungrouped = df.loc[:, ["Date", "Country", "Province", *data_cols_all]]
ncov_df_ungrouped.tail()
# Out:
#             Date         Country  Province  Confirmed  Infected  Deaths  \
# 14806 2020-04-13              US   Wyoming        275       274       1
# 14807 2020-04-13  Mainland China  Xinjiang         76         0       3
# 14808 2020-04-13          Canada     Yukon          8         8       0
# 14809 2020-04-13  Mainland China    Yunnan        184         8       2
# 14810 2020-04-13  Mainland China  Zhejiang       1267        27       1
#
#        Recovered
# 14806          0
# 14807         73
# 14808          0
# 14809        174
# 14810       1239

# %%
df_germany = ncov_df_ungrouped.loc[ncov_df_ungrouped["Country"] == "Germany", :].groupby("Date").sum()
df_germany['Country'] = 'Germany'
df_germany['Province'] = None
df_germany
# Out:
#             Confirmed  Infected  Deaths  Recovered  Country Province
# Date
# 2020-01-28          4         4       0          0  Germany     None
# 2020-01-29          4         4       0          0  Germany     None
# 2020-01-30          4         4       0          0  Germany     None
# 2020-01-31          5         5       0          0  Germany     None
# 2020-02-01          8         8       0          0  Germany     None
# ...               ...       ...     ...        ...      ...      ...
# 2020-04-09     118181     63167    2607      52407  Germany     None
# 2020-04-10     122171     65491    2767      53913  Germany     None
# 2020-04-11     124908     64772    2736      57400  Germany     None
# 2020-04-12     127854     64532    3022      60300  Germany     None
# 2020-04-13     130072     62578    3194      64300  Germany     None
#
# [77 rows x 6 columns]

# %%
df_test = pd.read_csv("../data/full-list-total-tests-for-covid-19.csv")
df_test.rename({"Cumulative total tests": "TotalTests"}, axis=1,inplace=True)
df_test["Date"] = pd.to_datetime(df_test["Date"])
df_test_germany = df_test[df_test['Entity'] == 'Germany']
df_test_germany.tail()
# Out:
#       Entity Code       Date  TotalTests
# 440  Germany  DEU 2020-03-08       87863
# 441  Germany  DEU 2020-03-15      215320
# 442  Germany  DEU 2020-03-22      563939
# 443  Germany  DEU 2020-03-29      924903
# 444  Germany  DEU 2020-04-05     1317887

# %%
result = pd.merge(df_germany,
                 df_test_germany[['Date','TotalTests']],
                 on='Date',
                 how = 'left')
from numpy import isnan
result.loc[0, ('TotalTests')] = 0 if isnan(result['TotalTests'][0]) else result['TotalTests'][0]
result['TotalTests'].interpolate(method='linear',inplace=True,limit_direction='both')
result['TotalTests'] = result['TotalTests'].astype(int)
result
# Out:
#          Date  Confirmed  Infected  Deaths  Recovered  Country Province  \
# 0  2020-01-28          4         4       0          0  Germany     None
# 1  2020-01-29          4         4       0          0  Germany     None
# 2  2020-01-30          4         4       0          0  Germany     None
# 3  2020-01-31          5         5       0          0  Germany     None
# 4  2020-02-01          8         8       0          0  Germany     None
# ..        ...        ...       ...     ...        ...      ...      ...
# 72 2020-04-09     118181     63167    2607      52407  Germany     None
# 73 2020-04-10     122171     65491    2767      53913  Germany     None
# 74 2020-04-11     124908     64772    2736      57400  Germany     None
# 75 2020-04-12     127854     64532    3022      60300  Germany     None
# 76 2020-04-13     130072     62578    3194      64300  Germany     None
#
#     TotalTests
# 0            0
# 1         2196
# 2         4393
# 3         6589
# 4         8786
# ..         ...
# 72     1317887
# 73     1317887
# 74     1317887
# 75     1317887
# 76     1317887
#
# [77 rows x 8 columns]

# %%
ger_scenario = model.Scenario(result, name="Germany", places=[("Germany", None)])

# %%
ger_scenario.show_record().tail()
# Out:
#          Date  Confirmed  Infected  Deaths  Recovered
# 72 2020-04-09     118181     63167    2607      52407
# 73 2020-04-10     122171     65491    2767      53913
# 74 2020-04-11     124908     64772    2736      57400
# 75 2020-04-12     127854     64532    3022      60300
# 76 2020-04-13     130072     62578    3194      64300

# %%
ger_scenario.growth_factor()
# Out:
#               Date      Group  GF > 1 [straight days]  GF < 1 [straight days]
# Germany 2020-04-13  Crossroad                       0                       5

# %%
ger_scenario.set_phase(
    start_dates=["17Feb2020", "03Mar2020", "11Mar2020","23Mar2020", "12Apr2020"],
    population=82790000
)
# Out:
#     start_date   end_date  population
# 1st  17Feb2020  02Mar2020    82790000
# 2nd  03Mar2020  10Mar2020    82790000
# 3rd  11Mar2020  22Mar2020    82790000
# 4th  23Mar2020  12Apr2020    82790000
# 5th  13Apr2020          -    82790000

# %%
ger_scenario.estimate(model.SIR)
# Out:
# Hyperparameter estimation of 1st phase.
# 	Estimator was created.
# 		100 trials finished in 0 min 8 sec.
# 		100 trials finished in 0 min 10 sec.
# 		100 trials finished in 0 min 10 sec.
# 		100 trials finished in 0 min 12 sec.
# 		100 trials finished in 0 min 15 sec.
# 		100 trials finished in 0 min 17 sec.
# 		100 trials finished in 0 min 19 sec.
# 		100 trials finished in 0 min 20 sec.
# 		100 trials finished in 0 min 24 sec.
# 		100 trials finished in 0 min 24 sec.
# 		100 trials finished in 0 min 24 sec.
# 	Successfully estimated.
# Hyperparameter estimation of 2nd phase.
# 	Estimator was created.
# 		100 trials finished in 0 min 7 sec.
# 	Successfully estimated.
# Hyperparameter estimation of 3rd phase.
# 	Estimator was created.
# 		100 trials finished in 0 min 7 sec.
# 	Successfully estimated.
# Hyperparameter estimation of 4th phase.
# 	Estimator was created.
# 		100 trials finished in 0 min 8 sec.
# 	Successfully estimated.
# Hyperparameter estimation of 5th phase.
# 	Estimator was created.
# 		100 trials
# Setting status of trial#1 as TrialState.FAIL because of the following error: OverflowError('Range exceeds valid bounds',)
# Traceback (most recent call last):
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "../model/model.py", line 378, in <lambda>
#     lambda x: self.objective(x),
#   File "../model/model.py", line 428, in objective
#     for (k, v) in param_dict.items()
#   File "../model/model.py", line 428, in <dictcomp>
#     for (k, v) in param_dict.items()
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 288, in suggest_uniform
#     return self._suggest(name, distribution)
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 715, in _suggest
#     self.study, trial, name, distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/tpe/sampler.py", line 135, in sample_independent
#     study, trial, param_name, param_distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/random.py", line 73, in sample_independent
#     return self._rng.uniform(param_distribution.low, param_distribution.high)
#   File "mtrand.pyx", line 1091, in numpy.random.mtrand.RandomState.uniform
# OverflowError: Range exceeds valid bounds
# Setting status of trial#2 as TrialState.FAIL because of the following error: OverflowError('Range exceeds valid bounds',)
# Traceback (most recent call last):
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "../model/model.py", line 378, in <lambda>
#     lambda x: self.objective(x),
#   File "../model/model.py", line 428, in objective
#     for (k, v) in param_dict.items()
#   File "../model/model.py", line 428, in <dictcomp>
#     for (k, v) in param_dict.items()
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 288, in suggest_uniform
#     return self._suggest(name, distribution)
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 715, in _suggest
#     self.study, trial, name, distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/tpe/sampler.py", line 135, in sample_independent
#     study, trial, param_name, param_distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/random.py", line 73, in sample_independent
#     return self._rng.uniform(param_distribution.low, param_distribution.high)
#   File "mtrand.pyx", line 1091, in numpy.random.mtrand.RandomState.uniform
# OverflowError: Range exceeds valid bounds
# Setting status of trial#4 as TrialState.FAIL because of the following error: OverflowError('Range exceeds valid bounds',)
# Traceback (most recent call last):
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "../model/model.py", line 378, in <lambda>
#     lambda x: self.objective(x),
#   File "../model/model.py", line 428, in objective
#     for (k, v) in param_dict.items()
#   File "../model/model.py", line 428, in <dictcomp>
#     for (k, v) in param_dict.items()
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 288, in suggest_uniform
#     return self._suggest(name, distribution)
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 715, in _suggest
#     self.study, trial, name, distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/tpe/sampler.py", line 135, in sample_independent
#     study, trial, param_name, param_distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/random.py", line 73, in sample_independent
#     return self._rng.uniform(param_distribution.low, param_distribution.high)
#   File "mtrand.pyx", line 1091, in numpy.random.mtrand.RandomState.uniform
# OverflowError: Range exceeds valid bounds
# Setting status of trial#6 as TrialState.FAIL because of the following error: OverflowError('Range exceeds valid bounds',)
# Traceback (most recent call last):
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "../model/model.py", line 378, in <lambda>
#     lambda x: self.objective(x),
#   File "../model/model.py", line 428, in objective
#     for (k, v) in param_dict.items()
#   File "../model/model.py", line 428, in <dictcomp>
#     for (k, v) in param_dict.items()
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 288, in suggest_uniform
#     return self._suggest(name, distribution)
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 715, in _suggest
#     self.study, trial, name, distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/tpe/sampler.py", line 135, in sample_independent
#     study, trial, param_name, param_distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/random.py", line 73, in sample_independent
#     return self._rng.uniform(param_distribution.low, param_distribution.high)
#   File "mtrand.pyx", line 1091, in numpy.random.mtrand.RandomState.uniform
# OverflowError: Range exceeds valid bounds
# Setting status of trial#0 as TrialState.FAIL because of the following error: OverflowError('Range exceeds valid bounds',)
# Traceback (most recent call last):
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "../model/model.py", line 378, in <lambda>
#     lambda x: self.objective(x),
#   File "../model/model.py", line 428, in objective
#     for (k, v) in param_dict.items()
#   File "../model/model.py", line 428, in <dictcomp>
#     for (k, v) in param_dict.items()
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 288, in suggest_uniform
#     return self._suggest(name, distribution)
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 715, in _suggest
#     self.study, trial, name, distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/tpe/sampler.py", line 135, in sample_independent
#     study, trial, param_name, param_distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/random.py", line 73, in sample_independent
#     return self._rng.uniform(param_distribution.low, param_distribution.high)
#   File "mtrand.pyx", line 1091, in numpy.random.mtrand.RandomState.uniform
# OverflowError: Range exceeds valid bounds
# Setting status of trial#5 as TrialState.FAIL because of the following error: OverflowError('Range exceeds valid bounds',)
# Traceback (most recent call last):
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "../model/model.py", line 378, in <lambda>
#     lambda x: self.objective(x),
#   File "../model/model.py", line 428, in objective
#     for (k, v) in param_dict.items()
#   File "../model/model.py", line 428, in <dictcomp>
#     for (k, v) in param_dict.items()
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 288, in suggest_uniform
#     return self._suggest(name, distribution)
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 715, in _suggest
#     self.study, trial, name, distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/tpe/sampler.py", line 135, in sample_independent
#     study, trial, param_name, param_distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/random.py", line 73, in sample_independent
#     return self._rng.uniform(param_distribution.low, param_distribution.high)
#   File "mtrand.pyx", line 1091, in numpy.random.mtrand.RandomState.uniform
# OverflowError: Range exceeds valid bounds
# Setting status of trial#3 as TrialState.FAIL because of the following error: OverflowError('Range exceeds valid bounds',)
# Traceback (most recent call last):
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "../model/model.py", line 378, in <lambda>
#     lambda x: self.objective(x),
#   File "../model/model.py", line 428, in objective
#     for (k, v) in param_dict.items()
#   File "../model/model.py", line 428, in <dictcomp>
#     for (k, v) in param_dict.items()
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 288, in suggest_uniform
#     return self._suggest(name, distribution)
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 715, in _suggest
#     self.study, trial, name, distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/tpe/sampler.py", line 135, in sample_independent
#     study, trial, param_name, param_distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/random.py", line 73, in sample_independent
#     return self._rng.uniform(param_distribution.low, param_distribution.high)
#   File "mtrand.pyx", line 1091, in numpy.random.mtrand.RandomState.uniform
# OverflowError: Range exceeds valid bounds
# Setting status of trial#7 as TrialState.FAIL because of the following error: OverflowError('Range exceeds valid bounds',)
# Traceback (most recent call last):
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "../model/model.py", line 378, in <lambda>
#     lambda x: self.objective(x),
#   File "../model/model.py", line 428, in objective
#     for (k, v) in param_dict.items()
#   File "../model/model.py", line 428, in <dictcomp>
#     for (k, v) in param_dict.items()
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 288, in suggest_uniform
#     return self._suggest(name, distribution)
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 715, in _suggest
#     self.study, trial, name, distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/tpe/sampler.py", line 135, in sample_independent
#     study, trial, param_name, param_distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/random.py", line 73, in sample_independent
#     return self._rng.uniform(param_distribution.low, param_distribution.high)
#   File "mtrand.pyx", line 1091, in numpy.random.mtrand.RandomState.uniform
# OverflowError: Range exceeds valid bounds
# Setting status of trial#8 as TrialState.FAIL because of the following error: OverflowError('Range exceeds valid bounds',)
# Traceback (most recent call last):
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "../model/model.py", line 378, in <lambda>
#     lambda x: self.objective(x),
#   File "../model/model.py", line 428, in objective
#     for (k, v) in param_dict.items()
#   File "../model/model.py", line 428, in <dictcomp>
#     for (k, v) in param_dict.items()
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 288, in suggest_uniform
#     return self._suggest(name, distribution)
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 715, in _suggest
#     self.study, trial, name, distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/tpe/sampler.py", line 135, in sample_independent
#     study, trial, param_name, param_distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/random.py", line 73, in sample_independent
#     return self._rng.uniform(param_distribution.low, param_distribution.high)
#   File "mtrand.pyx", line 1091, in numpy.random.mtrand.RandomState.uniform
# OverflowError: Range exceeds valid bounds
# Setting status of trial#9 as TrialState.FAIL because of the following error: OverflowError('Range exceeds valid bounds',)
# Traceback (most recent call last):
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "../model/model.py", line 378, in <lambda>
#     lambda x: self.objective(x),
#   File "../model/model.py", line 428, in objective
#     for (k, v) in param_dict.items()
#   File "../model/model.py", line 428, in <dictcomp>
#     for (k, v) in param_dict.items()
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 288, in suggest_uniform
#     return self._suggest(name, distribution)
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 715, in _suggest
#     self.study, trial, name, distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/tpe/sampler.py", line 135, in sample_independent
#     study, trial, param_name, param_distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/random.py", line 73, in sample_independent
#     return self._rng.uniform(param_distribution.low, param_distribution.high)
#   File "mtrand.pyx", line 1091, in numpy.random.mtrand.RandomState.uniform
# OverflowError: Range exceeds valid bounds
# Setting status of trial#10 as TrialState.FAIL because of the following error: OverflowError('Range exceeds valid bounds',)
# Traceback (most recent call last):
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "../model/model.py", line 378, in <lambda>
#     lambda x: self.objective(x),
#   File "../model/model.py", line 428, in objective
#     for (k, v) in param_dict.items()
#   File "../model/model.py", line 428, in <dictcomp>
#     for (k, v) in param_dict.items()
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 288, in suggest_uniform
#     return self._suggest(name, distribution)
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 715, in _suggest
#     self.study, trial, name, distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/tpe/sampler.py", line 135, in sample_independent
#     study, trial, param_name, param_distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/random.py", line 73, in sample_independent
#     return self._rng.uniform(param_distribution.low, param_distribution.high)
#   File "mtrand.pyx", line 1091, in numpy.random.mtrand.RandomState.uniform
# OverflowError: Range exceeds valid bounds
# Setting status of trial#11 as TrialState.FAIL because of the following error: OverflowError('Range exceeds valid bounds',)
# Traceback (most recent call last):
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "../model/model.py", line 378, in <lambda>
#     lambda x: self.objective(x),
#   File "../model/model.py", line 428, in objective
#     for (k, v) in param_dict.items()
#   File "../model/model.py", line 428, in <dictcomp>
#     for (k, v) in param_dict.items()
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 288, in suggest_uniform
#     return self._suggest(name, distribution)
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 715, in _suggest
#     self.study, trial, name, distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/tpe/sampler.py", line 135, in sample_independent
#     study, trial, param_name, param_distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/random.py", line 73, in sample_independent
#     return self._rng.uniform(param_distribution.low, param_distribution.high)
#   File "mtrand.pyx", line 1091, in numpy.random.mtrand.RandomState.uniform
# OverflowError: Range exceeds valid bounds
# Setting status of trial#12 as TrialState.FAIL because of the following error: OverflowError('Range exceeds valid bounds',)
# Traceback (most recent call last):
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/study.py", line 677, in _run_trial
#     result = func(trial)
#   File "../model/model.py", line 378, in <lambda>
#     lambda x: self.objective(x),
#   File "../model/model.py", line 428, in objective
#     for (k, v) in param_dict.items()
#   File "../model/model.py", line 428, in <dictcomp>
#     for (k, v) in param_dict.items()
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 288, in suggest_uniform
#     return self._suggest(name, distribution)
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/trial.py", line 715, in _suggest
#     self.study, trial, name, distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/tpe/sampler.py", line 135, in sample_independent
#     study, trial, param_name, param_distribution
#   File "/home/jakub/.local/lib/python3.6/site-packages/optuna/samplers/random.py", line 73, in sample_independent
#     return self._rng.uniform(param_distribution.low, param_distribution.high)
#   File "mtrand.pyx", line 1091, in numpy.random.mtrand.RandomState.uniform
# OverflowError: Range exceeds valid bounds
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-13-65128c5eda37> in <module>
# ----> 1 ger_scenario.estimate(model.SIR)
#
# ~/Studia/EpidemicSpreadModels/model/model.py in estimate(self, model, n_trials, same_tau)
#     896                     with warnings.catch_warnings():
#     897                         warnings.simplefilter("ignore")
# --> 898                         _ = self.estimator_dict[num].run(n_trials=n_trials)
#     899                     minutes, seconds = divmod(int((datetime.now() - est_start_time_run).total_seconds()), 60)
#     900                     print(f"finished in {minutes} min {seconds} sec.")
#
# ~/Studia/EpidemicSpreadModels/model/model.py in run(self, n_trials)
#     378             lambda x: self.objective(x),
#     379             n_trials=n_trials,
# --> 380             n_jobs=-1
#     381         )
#     382         param_dict = self.study.best_params.copy()
#
# ~/.local/lib/python3.6/site-packages/optuna/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     370                             func, 1, timeout, catch, callbacks, gc_after_trial, time_start
#     371                         )
# --> 372                         for _ in _iter
#     373                     )
#     374         finally:
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1015
#    1016             with self._backend.retrieval_context():
# -> 1017                 self.retrieve()
#    1018             # Make sure that we get a last message telling us we are done
#    1019             elapsed_time = time.time() - self._start_time
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in retrieve(self)
#     907             try:
#     908                 if getattr(self._backend, 'supports_timeout', False):
# --> 909                     self._output.extend(job.get(timeout=self.timeout))
#     910                 else:
#     911                     self._output.extend(job.get())
#
# /usr/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     642             return self._value
#     643         else:
# --> 644             raise self._value
#     645
#     646     def _set(self, i, obj):
#
# /usr/lib/python3.6/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     117         job, i, func, args, kwds = task
#     118         try:
# --> 119             result = (True, func(*args, **kwds))
#     120         except Exception as e:
#     121             if wrap_exception and func is not _helper_reraises_exception:
#
# ~/.local/lib/python3.6/site-packages/joblib/_parallel_backends.py in __call__(self, *args, **kwargs)
#     606     def __call__(self, *args, **kwargs):
#     607         try:
# --> 608             return self.func(*args, **kwargs)
#     609         except KeyboardInterrupt:
#     610             # We capture the KeyboardInterrupt and reraise it as
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~/.local/lib/python3.6/site-packages/optuna/study.py in _optimize_sequential(self, func, n_trials, timeout, catch, callbacks, gc_after_trial, time_start)
#     624                     break
#     625
# --> 626             self._run_trial_and_callbacks(func, catch, callbacks, gc_after_trial)
#     627
#     628             self._progress_bar.update((datetime.datetime.now() - time_start).total_seconds())
#
# ~/.local/lib/python3.6/site-packages/optuna/study.py in _run_trial_and_callbacks(self, func, catch, callbacks, gc_after_trial)
#     654         # type: (...) -> None
#     655
# --> 656         trial = self._run_trial(func, catch, gc_after_trial)
#     657         if callbacks is not None:
#     658             frozen_trial = self._storage.get_trial(trial._trial_id)
#
# ~/.local/lib/python3.6/site-packages/optuna/study.py in _run_trial(self, func, catch, gc_after_trial)
#     675
#     676         try:
# --> 677             result = func(trial)
#     678         except exceptions.TrialPruned as e:
#     679             message = "Setting status of trial#{} as {}. {}".format(
#
# ~/Studia/EpidemicSpreadModels/model/model.py in <lambda>(x)
#     376             self.study = optuna.create_study(direction="minimize")
#     377         self.study.optimize(
# --> 378             lambda x: self.objective(x),
#     379             n_trials=n_trials,
#     380             n_jobs=-1
#
# ~/Studia/EpidemicSpreadModels/model/model.py in objective(self, trial)
#     426             {
#     427                 k: trial.suggest_uniform(k, *v)
# --> 428                 for (k, v) in param_dict.items()
#     429             }
#     430         )
#
# ~/Studia/EpidemicSpreadModels/model/model.py in <dictcomp>(.0)
#     426             {
#     427                 k: trial.suggest_uniform(k, *v)
# --> 428                 for (k, v) in param_dict.items()
#     429             }
#     430         )
#
# ~/.local/lib/python3.6/site-packages/optuna/trial.py in suggest_uniform(self, name, low, high)
#     286             return self._set_new_param_or_get_existing(name, low, distribution)
#     287
# --> 288         return self._suggest(name, distribution)
#     289
#     290     def suggest_loguniform(self, name, low, high):
#
# ~/.local/lib/python3.6/site-packages/optuna/trial.py in _suggest(self, name, distribution)
#     713             trial = self.storage.get_trial(self._trial_id)
#     714             param_value = self.study.sampler.sample_independent(
# --> 715                 self.study, trial, name, distribution
#     716             )
#     717
#
# ~/.local/lib/python3.6/site-packages/optuna/samplers/tpe/sampler.py in sample_independent(self, study, trial, param_name, param_distribution)
#     133         if n < self._n_startup_trials:
#     134             return self._random_sampler.sample_independent(
# --> 135                 study, trial, param_name, param_distribution
#     136             )
#     137
#
# ~/.local/lib/python3.6/site-packages/optuna/samplers/random.py in sample_independent(self, study, trial, param_name, param_distribution)
#      71
#      72         if isinstance(param_distribution, distributions.UniformDistribution):
# ---> 73             return self._rng.uniform(param_distribution.low, param_distribution.high)
#      74         elif isinstance(param_distribution, distributions.LogUniformDistribution):
#      75             log_low = numpy.log(param_distribution.low)
#
# mtrand.pyx in numpy.random.mtrand.RandomState.uniform()
#
# OverflowError: Range exceeds valid bounds

# %%
e = model.Estimator(model.SIR, df_germany, 82790000)

# %%
print(df_germany)
e.run(100)

# %%
ger_scenario.accuracy_graph(phase_n=1)

# %%
ger_scenario.predict(days=10)
